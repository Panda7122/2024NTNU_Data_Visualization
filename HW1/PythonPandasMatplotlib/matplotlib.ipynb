# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
plt.figure()

# %%
plt.plot(np.array([4,6,3,10,7]))

# %%
plt.xlabel("input parameter (seconds)")
# Out:
# Text(0.5, 0, 'input parameter (seconds)')

# %%
plt.show()

# %%
x = [1,2,3,4,5]

# %%
y = [7,2,3,5.5,1]

# %%
plt.xticks(x,["b1","b2","b3","b4","b5"],rotation=-60)
# Out:
# ([<matplotlib.axis.XTick at 0x7fbaa4db0fd0>,
#   <matplotlib.axis.XTick at 0x7fbaa4f4c6d0>,
#   <matplotlib.axis.XTick at 0x7fbaa4f4c590>,
#   <matplotlib.axis.XTick at 0x7fbaa4feddd0>,
#   <matplotlib.axis.XTick at 0x7fbaa4ff96d0>],
#  <a list of 5 Text xticklabel objects>)

# %%
plt.grid(True)

# %%
plt.bar(x,y,align='center')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.show()

# %%
a = np.random.uniform(1,10,7)

# %%
print(a)
# Out:
# [4.04789994 5.14964175 6.29054017 6.34582196 2.12232722 9.10443854
#  2.47965886]

# %%
L = ["b1", "b2", "b3", "b4", "b5", "b6", "b7"]

# %%
plt.pie(a,labels = L)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fbaa4ffe890>,
#   <matplotlib.patches.Wedge at 0x7fbaa51d68d0>,
#   <matplotlib.patches.Wedge at 0x7fbaa5007310>,
#   <matplotlib.patches.Wedge at 0x7fbaa5007210>,
#   <matplotlib.patches.Wedge at 0x7fbaa50d4a50>,
#   <matplotlib.patches.Wedge at 0x7fbaa50db750>,
#   <matplotlib.patches.Wedge at 0x7fbaa5014f50>],
#  [Text(1.0303308590827163, 0.38525098419325554, 'b1'),
#   Text(0.42832327851338137, 1.0131826928464327, 'b2'),
#   Text(-0.6313194907521817, 0.9007972583197653, 'b3'),
#   Text(-1.0863865021603387, -0.17252352860936004, 'b4'),
#   Text(-0.6785600711514381, -0.865769155051712, 'b5'),
#   Text(0.3539783252780046, -1.0414890038946063, 'b6'),
#   Text(1.0736812961397642, -0.2391829306611078, 'b7')])

# %%
plt.title("A pie chart")
# Out:
# Text(0.5, 1.0, 'A pie chart')

# %%
plt.show()

# %%
x = np.random.uniform(0,0.1,1000)

# %%
plt.hist(x,100)
# Out:
# (array([10.,  8., 18., 11., 12.,  8.,  8.,  9.,  9.,  5.,  6., 10.,  7.,
#         12.,  7., 16., 10.,  8., 11.,  9.,  7., 12., 10.,  8., 13., 10.,
#          4.,  9.,  8., 10.,  9.,  6., 10.,  4.,  8., 11., 13.,  9., 13.,
#         17., 14.,  9.,  7.,  8.,  4., 11., 14., 11., 11.,  5.,  5., 12.,
#          9.,  8., 12., 16., 16.,  3., 11.,  7.,  8.,  8.,  8., 14., 10.,
#         14., 14.,  7., 22., 12.,  4.,  9., 12.,  5., 11.,  8., 11., 12.,
#          9.,  9.,  8., 10.,  8.,  9., 11., 13.,  7.,  9., 10., 12., 13.,
#         16., 12., 15., 10., 10.,  6.,  9., 14., 13.]),
#  array([3.86393491e-05, 1.03798511e-03, 2.03733086e-03, 3.03667662e-03,
#         4.03602237e-03, 5.03536813e-03, 6.03471388e-03, 7.03405964e-03,
#         8.03340540e-03, 9.03275115e-03, 1.00320969e-02, 1.10314427e-02,
#         1.20307884e-02, 1.30301342e-02, 1.40294799e-02, 1.50288257e-02,
#         1.60281714e-02, 1.70275172e-02, 1.80268630e-02, 1.90262087e-02,
#         2.00255545e-02, 2.10249002e-02, 2.20242460e-02, 2.30235917e-02,
#         2.40229375e-02, 2.50222832e-02, 2.60216290e-02, 2.70209748e-02,
#         2.80203205e-02, 2.90196663e-02, 3.00190120e-02, 3.10183578e-02,
#         3.20177035e-02, 3.30170493e-02, 3.40163951e-02, 3.50157408e-02,
#         3.60150866e-02, 3.70144323e-02, 3.80137781e-02, 3.90131238e-02,
#         4.00124696e-02, 4.10118153e-02, 4.20111611e-02, 4.30105069e-02,
#         4.40098526e-02, 4.50091984e-02, 4.60085441e-02, 4.70078899e-02,
#         4.80072356e-02, 4.90065814e-02, 5.00059271e-02, 5.10052729e-02,
#         5.20046187e-02, 5.30039644e-02, 5.40033102e-02, 5.50026559e-02,
#         5.60020017e-02, 5.70013474e-02, 5.80006932e-02, 5.90000389e-02,
#         5.99993847e-02, 6.09987305e-02, 6.19980762e-02, 6.29974220e-02,
#         6.39967677e-02, 6.49961135e-02, 6.59954592e-02, 6.69948050e-02,
#         6.79941508e-02, 6.89934965e-02, 6.99928423e-02, 7.09921880e-02,
#         7.19915338e-02, 7.29908795e-02, 7.39902253e-02, 7.49895710e-02,
#         7.59889168e-02, 7.69882626e-02, 7.79876083e-02, 7.89869541e-02,
#         7.99862998e-02, 8.09856456e-02, 8.19849913e-02, 8.29843371e-02,
#         8.39836828e-02, 8.49830286e-02, 8.59823744e-02, 8.69817201e-02,
#         8.79810659e-02, 8.89804116e-02, 8.99797574e-02, 9.09791031e-02,
#         9.19784489e-02, 9.29777947e-02, 9.39771404e-02, 9.49764862e-02,
#         9.59758319e-02, 9.69751777e-02, 9.79745234e-02, 9.89738692e-02,
#         9.99732149e-02]),
#  <a list of 100 Patch objects>)

# %%
plt.show()

# %%
x = np.random.uniform(1,100,50)

# %%
y = np.random.normal(20, 10, 50)

# %%
plt.scatter(x,y)

# %%
plt.show()

# %%
x = np.random.uniform(1,100,50)

# %%
print(x)
# Out:
# [73.50903542 59.55493311 88.5554754  28.57602056 22.5487385  94.77004794
#  87.64958967 61.18546447 16.77284159 58.08070908  6.7581067  20.21174131
#  26.79128988 80.86165762 39.41174445 36.87653226 13.89132978 37.93433276
#  54.33077255 21.70521333 65.98621044 43.79453244 46.12265179 87.21923967
#  68.77800216 52.13673302 16.18968223 60.78075207 61.58798573 46.26911326
#  46.63583509 64.45768561 20.56854756  6.57968193 82.68080083 92.60829342
#  90.49663381 78.07329482 16.04474989 81.53495546 17.89322426 37.07232716
#  36.39379629 41.39339635 15.98881623 37.52784283 78.92803987 51.66916589
#  27.11125436 10.85071589]

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fbaa6536490>,
#   <matplotlib.lines.Line2D at 0x7fbaa6536a50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fbaa6536f50>,
#   <matplotlib.lines.Line2D at 0x7fbaa652c850>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fbaa652c810>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fbaa653e9d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fbaa653eed0>],
#  'means': []}

# %%
plt.show()
